# %% [markdown]
# # Data Analysis
# ### Samuel Mendez
#
# This journal defines functions to extract valuable information from the clean data we created in the preprocessing journal. The various functions defined allow the user to filter by subscription type. 365 Data Science can then view the most prominent patterns of pages visited based on subsciption type. The following functions are defined:
# `Page count` is the most fundamental metric; it counts how many times each page can be found in all user journeys.
# `Page presence` is similar to ‘page count’ but counts each page only once if it exists in a journey; it shows how many times each page is part of a journey.
# `Page destination` is a metric that shows the most frequent follow-ups after every page. It looks at every page and counts which pages follow next. If one is interested in what the users do after visiting page X, they can consult this metric.
# `Page sequences`: the most popular sequence of pages given the number of pages a user specifies.
# `Journey length`: a metric that considers the average length of a user journey in terms of pages.

# %%
# import libraries
import pandas as pd
import numpy as np
from collections import Counter

# %%
# import clean data
data = pd.read_csv('clean_data.csv')

# %%
data.head(10)
# Out:
#    user_id subscription_type  \
# 0     1516            Annual
# 1     3395            Annual
# 2    10107            Annual
# 3    11145           Monthly
# 4    12400           Monthly
# 5    13082           Monthly
# 6    14415           Monthly
# 7    15630            Annual
# 8    16589         Quarterly
# 9    19458            Annual
#
#                                         user_journey
# 0  Homepage-Log in-Other-Sign up-Log in-Homepage-...
# 1  Other-Pricing-Sign up-Log in-Homepage-Pricing-...
# 2  Homepage-Career tracks-Homepage-Career tracks-...
# 3  Homepage-Log in-Homepage-Log in-Homepage-Log i...
# 4  Homepage-Career tracks-Sign up-Log in-Other-Ca...
# 5          Checkout-Homepage-Sign up-Log in-Checkout
# 6  Pricing-Sign up-Pricing-Sign up-Homepage-Log i...
# 7  Log in-Checkout-Pricing-Checkout-Other-Homepag...
# 8  Homepage-Career tracks-Homepage-Career tracks-...
# 9  Homepage-Sign up-Log in-Other-Homepage-Pricing...

# %%
# check for missing values
data.isnull().sum()
# Out:
# user_id              0
# subscription_type    0
# user_journey         0
# dtype: int64

# %%
# define a function that counts how times a page can be found in all user journeys

def page_count(df, subtype = 'All', target_column = 'user_journey'):
    df_copy = df.copy()
    # drop missing values 
    df_copy = df_copy.dropna()
    
    # choose membership type
    if subtype != 'All':
        df_copy = df_copy[df_copy['subscription_type'].str.contains(subtype)]

            
    # split the pages at the hyphen
    pages_list = df_copy[target_column].str.split('-')
    # flatten the rows of list
    pages = [page for sublist in pages_list for page in sublist]
    # create a series to count the values  
    pages_count = pd.Series(pages).value_counts()
        
        
    
    return pages_count

# %%
page_count(data, subtype = 'Quarterly')
# Out:
# Homepage                    109
# Log in                       94
# Sign up                      65
# Checkout                     63
# Career tracks                36
# Courses                      36
# Pricing                      33
# Other                        26
# Career track certificate     18
# Course certificate           10
# Coupon                        8
# Resources center              8
# Success stories               4
# Upcoming courses              2
# About us                      1
# Name: count, dtype: int64

# %%
# define a function that counts if a page is found in user's journeys

def page_presence(df, subtype = 'All', target_column = 'user_journey'):
    df_copy = df.copy()
    # drop missing values 
    df_copy = df_copy.dropna()
        
    # choose membership type
    if subtype != 'All':
        df_copy = df_copy[df_copy['subscription_type'].str.contains(subtype)]
        
    # split the pages at the hyphen
    pages_list = df_copy[target_column].str.split('-')
    
    # convert each list to a set to remove duplicates
    pages_list = pages_list.apply(lambda x: list(set(x)) if isinstance(x, list) else x)
    
    # flatten the rows of list
    pages = [page for sublist in pages_list for page in sublist]
        
    # create a series to count the values  
    pages_count = pd.Series(pages).value_counts()

    
    return pages_count

# %%
page_presence(data, subtype = 'Quarterly')
# Out:
# Checkout                    38
# Sign up                     36
# Homepage                    32
# Log in                      32
# Pricing                     16
# Other                       16
# Courses                     15
# Career tracks               13
# Career track certificate     8
# Course certificate           7
# Coupon                       6
# Resources center             4
# Success stories              2
# Upcoming courses             2
# About us                     1
# Name: count, dtype: int64

# %%
# define a function that shows the most frequent follow-ups after every page

def page_destination(df, subtype = 'All', target_column = 'user_journey'):
    df_copy = df.copy()
    # drop missing values 
    df_copy = df_copy.dropna()
        
    # choose membership type
    if subtype != 'All':
        df_copy = df_copy[df_copy['subscription_type'].str.contains(subtype)]
    
    # split each row at the hyphen
    pages_list = df_copy[target_column].str.split('-')
    
    
    # count the following page after every page
    page_pair_count = Counter()
    
    for pair in pages_list:
        if isinstance(pair, list):
            for i in range(len(pair)-1):
                page_pair = (pair[i], pair[i+1])
                page_pair_count[page_pair] += 1
    
    return page_pair_count

# %%
page_destination(data, subtype = 'All')
# Out:
# Counter({('Homepage', 'Log in'): 953,
#          ('Log in', 'Homepage'): 817,
#          ('Log in', 'Checkout'): 701,
#          ('Homepage', 'Pricing'): 449,
#          ('Sign up', 'Log in'): 394,
#          ('Homepage', 'Career tracks'): 357,
#          ('Career tracks', 'Courses'): 353,
#          ('Resources center', 'Other'): 344,
#          ('Homepage', 'Sign up'): 341,
#          ('Other', 'Resources center'): 295,
#          ('Pricing', 'Checkout'): 291,
#          ('Courses', 'Career tracks'): 290,
#          ('Other', 'Log in'): 290,
#          ('Sign up', 'Homepage'): 279,
#          ('Homepage', 'Courses'): 246,
#          ('Sign up', 'Checkout'): 222,
#          ('Log in', 'Other'): 213,
#          ('Courses', 'Sign up'): 213,
#          ('Career tracks', 'Sign up'): 198,
#          ('Checkout', 'Homepage'): 196,
#          ('Career tracks', 'Homepage'): 182,
#          ('Courses', 'Homepage'): 175,
#          ('Career track certificate', 'Career tracks'): 173,
#          ('Log in', 'Coupon'): 170,
#          ('Pricing', 'Homepage'): 162,
#          ('Checkout', 'Log in'): 157,
#          ('Log in', 'Sign up'): 140,
#          ('Other', 'Homepage'): 138,
#          ('Pricing', 'Sign up'): 132,
#          ('Checkout', 'Pricing'): 126,
#          ('Homepage', 'Career track certificate'): 117,
#          ('Pricing', 'Courses'): 112,
#          ('Courses', 'Log in'): 110,
#          ('Courses', 'Pricing'): 99,
#          ('Pricing', 'Log in'): 95,
#          ('Career tracks', 'Career track certificate'): 88,
#          ('Other', 'Coupon'): 88,
#          ('Career tracks', 'Pricing'): 87,
#          ('Coupon', 'Homepage'): 85,
#          ('Checkout', 'Coupon'): 80,
#          ('Pricing', 'Career tracks'): 67,
#          ('Homepage', 'Course certificate'): 66,
#          ('Career track certificate', 'Sign up'): 66,
#          ('Coupon', 'Checkout'): 64,
#          ('Sign up', 'Coupon'): 64,
#          ('Pricing', 'Career track certificate'): 61,
#          ('Sign up', 'Other'): 60,
#          ('Other', 'Sign up'): 58,
#          ('Other', 'Pricing'): 57,
#          ('Sign up', 'Courses'): 55,
#          ('Homepage', 'Resources center'): 51,
#          ('Sign up', 'Pricing'): 50,
#          ('Log in', 'Courses'): 50,
#          ('Sign up', 'Career tracks'): 50,
#          ('Course certificate', 'Career track certificate'): 49,
#          ('Career tracks', 'Log in'): 48,
#          ('Coupon', 'Log in'): 46,
#          ('Career track certificate', 'Pricing'): 44,
#          ('Courses', 'Career track certificate'): 42,
#          ('Resources center', 'Homepage'): 41,
#          ('Other', 'Courses'): 40,
#          ('Pricing', 'Resources center'): 40,
#          ('Sign up', 'Career track certificate'): 39,
#          ('Career track certificate', 'Courses'): 39,
#          ('Courses', 'Coupon'): 38,
#          ('Log in', 'Pricing'): 38,
#          ('Course certificate', 'Courses'): 37,
#          ('Career track certificate', 'Course certificate'): 37,
#          ('Log in', 'Resources center'): 36,
#          ('Career track certificate', 'Homepage'): 35,
#          ('Checkout', 'Other'): 34,
#          ('Resources center', 'Log in'): 33,
#          ('Homepage', 'Other'): 33,
#          ('Upcoming courses', 'Courses'): 33,
#          ('Resources center', 'Courses'): 32,
#          ('Other', 'Checkout'): 27,
#          ('Courses', 'Upcoming courses'): 27,
#          ('Course certificate', 'Sign up'): 26,
#          ('Other', 'Career tracks'): 26,
#          ('Homepage', 'Instructors'): 25,
#          ('Courses', 'Course certificate'): 25,
#          ('Courses', 'Resources center'): 24,
#          ('Pricing', 'Other'): 24,
#          ('Upcoming courses', 'Career tracks'): 24,
#          ('Pricing', 'Coupon'): 23,
#          ('Courses', 'Other'): 23,
#          ('Career tracks', 'Upcoming courses'): 23,
#          ('Other', 'Career track certificate'): 22,
#          ('Instructors', 'Homepage'): 22,
#          ('Career tracks', 'Coupon'): 22,
#          ('Pricing', 'Course certificate'): 22,
#          ('Career track certificate', 'Resources center'): 19,
#          ('Resources center', 'Pricing'): 19,
#          ('Career tracks', 'Resources center'): 19,
#          ('Course certificate', 'Pricing'): 19,
#          ('Course certificate', 'Homepage'): 18,
#          ('Career track certificate', 'Log in'): 18,
#          ('Career tracks', 'Other'): 18,
#          ('Coupon', 'Other'): 16,
#          ('Resources center', 'Career track certificate'): 16,
#          ('Checkout', 'Courses'): 16,
#          ('Pricing', 'Upcoming courses'): 14,
#          ('Course certificate', 'Upcoming courses'): 14,
#          ('Course certificate', 'Career tracks'): 14,
#          ('Other', 'Success stories'): 14,
#          ('Log in', 'Career tracks'): 14,
#          ('Resources center', 'Course certificate'): 14,
#          ('Checkout', 'Sign up'): 14,
#          ('Resources center', 'Career tracks'): 13,
#          ('Career tracks', 'Course certificate'): 13,
#          ('Other', 'Course certificate'): 13,
#          ('Blog', 'Other'): 12,
#          ('Homepage', 'Coupon'): 12,
#          ('Career track certificate', 'Other'): 11,
#          ('Sign up', 'Resources center'): 11,
#          ('Course certificate', 'Log in'): 11,
#          ('Career track certificate', 'Coupon'): 11,
#          ('Coupon', 'Pricing'): 10,
#          ('Course certificate', 'Resources center'): 10,
#          ('Homepage', 'Upcoming courses'): 10,
#          ('Upcoming courses', 'Resources center'): 10,
#          ('Sign up', 'Course certificate'): 9,
#          ('Log in', 'Career track certificate'): 9,
#          ('Career tracks', 'Checkout'): 8,
#          ('Coupon', 'Sign up'): 8,
#          ('Resources center', 'Upcoming courses'): 8,
#          ('Courses', 'Checkout'): 8,
#          ('Resources center', 'Sign up'): 7,
#          ('Upcoming courses', 'Pricing'): 7,
#          ('Other', 'Blog'): 7,
#          ('Upcoming courses', 'Course certificate'): 7,
#          ('Success stories', 'Resources center'): 7,
#          ('Checkout', 'Resources center'): 7,
#          ('Resources center', 'Coupon'): 7,
#          ('Career tracks', 'Success stories'): 7,
#          ('Course certificate', 'Coupon'): 7,
#          ('Upcoming courses', 'Other'): 7,
#          ('Upcoming courses', 'Career track certificate'): 7,
#          ('Instructors', 'Courses'): 7,
#          ('Instructors', 'Pricing'): 6,
#          ('About us', 'Other'): 6,
#          ('Success stories', 'Homepage'): 6,
#          ('Success stories', 'Career tracks'): 6,
#          ('Coupon', 'Career tracks'): 6,
#          ('Resources center', 'Checkout'): 5,
#          ('Homepage', 'About us'): 5,
#          ('Homepage', 'Checkout'): 5,
#          ('Pricing', 'Success stories'): 5,
#          ('Career track certificate', 'Upcoming courses'): 5,
#          ('Course certificate', 'Other'): 5,
#          ('Upcoming courses', 'Homepage'): 5,
#          ('Courses', 'Success stories'): 5,
#          ('Homepage', 'Success stories'): 4,
#          ('Success stories', 'Career track certificate'): 4,
#          ('Resources center', 'Success stories'): 4,
#          ('Success stories', 'Checkout'): 4,
#          ('Success stories', 'Log in'): 4,
#          ('Other', 'Upcoming courses'): 4,
#          ('Success stories', 'Other'): 4,
#          ('Coupon', 'Courses'): 4,
#          ('Checkout', 'Career tracks'): 4,
#          ('Career track certificate', 'Success stories'): 4,
#          ('Homepage', 'Blog'): 4,
#          ('Other', 'About us'): 4,
#          ('Upcoming courses', 'Coupon'): 4,
#          ('Success stories', 'Pricing'): 3,
#          ('Coupon', 'Resources center'): 3,
#          ('Checkout', 'Course certificate'): 3,
#          ('About us', 'Pricing'): 3,
#          ('Success stories', 'Sign up'): 3,
#          ('Courses', 'Instructors'): 3,
#          ('Career tracks', 'Instructors'): 3,
#          ('Upcoming courses', 'Log in'): 2,
#          ('Career track certificate', 'Checkout'): 2,
#          ('Pricing', 'Blog'): 2,
#          ('Upcoming courses', 'Success stories'): 2,
#          ('Resources center', 'About us'): 2,
#          ('Checkout', 'Success stories'): 2,
#          ('Checkout', 'Career track certificate'): 2,
#          ('Log in', 'Course certificate'): 2,
#          ('Log in', 'Instructors'): 2,
#          ('Instructors', 'Other'): 2,
#          ('Success stories', 'Blog'): 2,
#          ('Blog', 'Homepage'): 2,
#          ('Instructors', 'About us'): 2,
#          ('Coupon', 'Instructors'): 2,
#          ('About us', 'Resources center'): 2,
#          ('About us', 'Homepage'): 2,
#          ('Courses', 'Blog'): 2,
#          ('Success stories', 'Upcoming courses'): 2,
#          ('Career track certificate', 'About us'): 2,
#          ('Instructors', 'Career track certificate'): 2,
#          ('Career track certificate', 'Instructors'): 2,
#          ('Blog', 'Courses'): 2,
#          ('Sign up', 'Upcoming courses'): 1,
#          ('Sign up', 'Blog'): 1,
#          ('Blog', 'Log in'): 1,
#          ('Course certificate', 'Success stories'): 1,
#          ('Success stories', 'Courses'): 1,
#          ('Log in', 'Blog'): 1,
#          ('Checkout', 'Instructors'): 1,
#          ('Course certificate', 'Checkout'): 1,
#          ('Instructors', 'Log in'): 1,
#          ('Log in', 'About us'): 1,
#          ('About us', 'Sign up'): 1,
#          ('Sign up', 'About us'): 1,
#          ('Coupon', 'About us'): 1,
#          ('Blog', 'Resources center'): 1,
#          ('Resources center', 'Instructors'): 1,
#          ('About us', 'Career track certificate'): 1,
#          ('Upcoming courses', 'About us'): 1,
#          ('About us', 'Instructors'): 1,
#          ('Blog', 'Checkout'): 1,
#          ('About us', 'Courses'): 1,
#          ('Success stories', 'Coupon'): 1,
#          ('About us', 'Upcoming courses'): 1,
#          ('Upcoming courses', 'Sign up'): 1,
#          ('Pricing', 'Instructors'): 1,
#          ('About us', 'Success stories'): 1,
#          ('Blog', 'Pricing'): 1,
#          ('About us', 'Checkout'): 1,
#          ('Success stories', 'About us'): 1})

# %%
# define a function returns the most popular sequence given the number of pages in a sequence

def page_sequence(df, sequence_size, subtype = 'All', target_column = 'user_journey'):
    df_copy = df.copy()
    # drop na
    df_copy = df_copy.dropna()
    
    # filter by subscription type
    if subtype != 'All':
        df_copy = df_copy[df_copy['subcription_type'].str.contains(subtype)]
    
    # split strings at hyphen
    pages_list = df_copy[target_column].str.split('-')
    
    # count the occurance of page sequence once per row
    sequence_count = Counter()
    
    for sequence in pages_list:
        if len(sequence) >= sequence_size:
            for i in range(len(sequence)-sequence_size +1):
                sequence_group = tuple(sequence[i:i + sequence_size])
                sequence_count[sequence_group] += 1
    
    top_sequence, count = sequence_count.most_common(1)[0]
    
    return top_sequence, count

# %%
page_sequence(data, sequence_size = 4)
# Out:
# (('Log in', 'Homepage', 'Log in', 'Checkout'), 49)

# %%
# def function to check the average number of user page visits

def avg_journey(df, subtype = 'All', target_column = 'user_journey'):
    df_copy = df.copy()
    
    # drop missing values
    df_copy = df_copy.dropna()
    
    # filter by subscription type
    if subtype != 'All':
        df_copy = df_copy[df_copy['subscription_type'].str.contains(subtype)]
    
    # seperate strings at hyphen
    pages_list = df_copy[target_column].str.split('-')
    
    # count the length of every row
    journey_length = pages_list.apply(len)
    
    # Average journey 
    avg_visits = pd.DataFrame(journey_length).mean().round(1)
    
    return print("Average journey for", subtype, "subscribers:", avg_visits)

# %%
avg_journey(data, subtype = 'All')
# Out:
# Average journey for All subscribers: user_journey    3.6
# dtype: float64

# %% [markdown]
# End of journal.
